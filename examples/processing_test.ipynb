# %%
import numpy as np
import pandas as pd
import pprint as pprint
from detprocess.process import Processing
from pytesdaq.io import FilterH5IO
import warnings
warnings.filterwarnings('ignore')

# %%
raw_path = '/sdata1/runs/run20/processed/threshtrig_Co_12hr_I2_D20220915_T224645'
config_file = '/home/serfass/workspace/processing/process_run20.yaml'
myproc = Processing(raw_path, config_file, processing_id='testproc')
# Out:
# INFO: Found total of 394 files from 11 different series number!
# INFO: Filter file /home/serfass/workspace/processing/filter_r20_dev.hdf5 has been loaded!

# %%
data = myproc.process(nevents=1, save_hdf5=False, nb_cores=1)
# Out:
# INFO: settings new file list
# INFO: Number of events = 0 (memory = 0.0 MB)
# INFO: Requested nb events reached. Stopping processing!
# INFO: Feature processing done!

# %%
data_dict = data.to_dict()
data_dict
# Out:
# {'baseline_pre_CPDv21Ge': {0: -2.9089754689476676e-06},
#  'dumpnumber': {0: 1.0},
#  'energyabsorbed_CPDv21Ge': {0: 8.259152930677683e-18},
#  'eventid': {0: 1.0},
#  'eventindex': {0: 1.0},
#  'eventnumber': {0: 100001.0},
#  'eventtime': {0: 1663144231.06},
#  'integral_CPDv21Ge': {0: -2.9140535825347905e-09},
#  'maximum_CPDv21Ge': {0: -2.8741548538208007e-06},
#  'minimum_CPDv21Ge': {0: -2.9621612548828125e-06},
#  'ofamp_constrained_CPDv21Ge': {0: -1.146345808764678e-08},
#  'ofamp_constrained_TotIrPt': {0: -2.3743513731665755e-09},
#  'ofamp_nodelay_TotIrPt': {0: 1.8657573628316773e-09},
#  'ofamp_unconstrained_TotIrPt': {0: 3.6222312552665152e-09},
#  'ofamp_unconstrained_glitch_CPDv21Ge': {0: 2.9246904214404443e-08},
#  'ofchi2_constrained_CPDv21Ge': {0: 25747.508991745068},
#  'ofchi2_constrained_TotIrPt': {0: 62133.74427040036},
#  'ofchi2_nodelay_TotIrPt': {0: 62136.82486203748},
#  'ofchi2_unconstrained_TotIrPt': {0: 62123.05464460638},
#  'ofchi2_unconstrained_glitch_CPDv21Ge': {0: 25688.140528686352},
#  'oft0_constrained_CPDv21Ge': {0: -0.0001072},
#  'oft0_constrained_TotIrPt': {0: -0.0002232},
#  'oft0_unconstrained_TotIrPt': {0: 0.004504},
#  'oft0_unconstrained_glitch_CPDv21Ge': {0: -0.0099032},
#  'output_gain_CPDv21Ge': {0: 50.0},
#  'output_gain_IrPtTESBig': {0: 50.0},
#  'output_gain_IrPtTESSmall': {0: 50.0},
#  'processing_id': {0: 'testproc'},
#  'runtype': {0: 1.0},
#  'seriesnumber': {0: 220220915224648.0},
#  'tes_bias_CPDv21Ge': {0: '0.0001796092796092796'},
#  'tes_bias_IrPtTESBig': {0: '0.00024993894993894993'},
#  'tes_bias_IrPtTESSmall': {0: '7.020757020757026e-05'},
#  'triggeramp': {0: nan},
#  'triggertime': {0: nan},
#  'triggertype': {0: 3.0}}

# %%
myfilter = FilterH5IO('/home/serfass/workspace/processing/filter_r20_dev.hdf5')
filter_data = myfilter.describe()
# Out:
# Filter file: /home/serfass/workspace/processing/filter_r20_dev.hdf5:
# =====================================================================
#
# /IrPtTESSmall+IrPtTESBig/psd: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall+IrPtTESBig/psd_fold_total: pandas.Series (12501,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall+IrPtTESBig/template: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall|IrPtTESBig/psd: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall|IrPtTESBig/psd_fold: pandas.Series (12501,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall|IrPtTESBig/template: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall/psd: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall/psd_fold: pandas.Series (12501,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall/template: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESSmall/template_3poles: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESBig/psd: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESBig/psd_fold: pandas.Series (12501,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESBig/template: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /IrPtTESBig/template_3poles: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /CPDv21Ge/psd: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /CPDv21Ge/psd_fold: pandas.Series (12501,), metadata: {'version': 23, 'comment': 'just a comment'}
# /CPDv21Ge/psd_fold_strict: pandas.Series (12501,), metadata: {'version': 23, 'comment': 'just a comment'}
# /CPDv21Ge/psd_strict: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /CPDv21Ge/template: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}
# /CPDv21Ge/template_glitch: pandas.Series (25000,), metadata: {'version': 23, 'comment': 'just a comment'}

# %%
myfilter.plot_psd('CPDv21Ge', fold=True, unit='pA')
