# %% [markdown]
# # Test Reading of YAML files

# %%
from detprocess import YamlConfig
from pprint import pprint

# %% [markdown]
# #### Read file

# %%
sample_rate = 1.25e6
available_channels = ['Melange025pcLeft','Melange025pcRight', 'Melange4pc1ch', 'Melange1pc1ch']

yaml_obj = YamlConfig('process_example.yaml', available_channels, sample_rate=sample_rate)

# %% [markdown]
# ### Print

# %%
config = yaml_obj.get_config()

# %%
pprint(config)
# Out:
# {'didv': {'channels': {}, 'overall': {}},
#  'feature': {'channel_list': ['Melange1pc1ch',
#                               'Melange025pcLeft',
#                               'Melange025pcRight',
#                               'Melange4pc1ch'],
#              'channels': {'Melange025pcLeft': {'baseline': {'nb_pretrigger_samples': 12500,
#                                                             'nb_samples': 25000,
#                                                             'run': True,
#                                                             'window_max_from_trig_usec': -2000,
#                                                             'window_min_from_start_usec': 0},
#                                                'baseline_end': {'base_algorithm': 'baseline',
#                                                                 'nb_pretrigger_samples': 12500,
#                                                                 'nb_samples': 25000,
# ...
